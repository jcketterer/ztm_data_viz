# %% [markdown]
# # Libraries and Data

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/Business Analyst course/Data Visualization/Distribution Charts and Data Viz Basics

# %%
# Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.graph_objects as go

# %%
# Load the data
df = pd.read_csv("XXXX.csv")
df.head()

# %%
# Information about the df
df.info()

# %% [markdown]
# # Customization Matplotlib

# %%
# Defining the plot size
fig, ax = plt.subplots(figsize = (15, 6))

# Add a Vertical line
ax.axvline(df.Total.median(),
           color = 'black',
           ls = "dashed",
           label = "Median Total Power")

# Add a horizontal line
ax.axhline(50,
           color = 'blue',
           ls = 'dotted',
           label = "Line at frequency of 50")

# add something to yticks
plt.yticks(ticks = y_pos,
           labels = data['Country name'])
plt.yticks([0.3, 0.7],
           labels = ["0.3", "0.7"],
           color = "grey",
           size = 7)

# add something to xticks
plt.xticks(ticks = angles[:-1],
           labels = categories,
           rotation = 0,
           color = 'black',
           size = 12
           )

# Set a min and max limit to the y and x axis
plt.ylim(0,1)
plt.xlim(0,1)

# Change the font size
ax.tick_params(axis = "both", labelsize = 15)

# Add a title
fig.suptitle('Happiness of the top 10 countries, ranked', fontsize = 15)

# X and Y labels
plt.xlabel('Countries', fontsize = 15)
plt.ylabel('Generosity Score', fontsize = 15)

# Plotting
ax.legend()
plt.show()

# %% [markdown]
# # Customization Seaborn

# %%
sns.set_theme(style = "darkgrid")
